# %% [markdown]
# # Singapore Flat Resale Prices 1990-Present

# %% [markdown]
# - Month - Month of sale
# - Type - Designated residential area with its own amenities, infrastructure, and community facilities
# - Flat Type - Classification of units by room size. They range from 2 to 5 rooms, 3Gen units, and Executive units.
# - Block - A HDB building comprising multiple flats or apartments
# - Street Name - Name of the road the HDB flat is located along
# - Storey Range - Estimated range of floors the unit sold was located on
# - Floor Area - Total interior space within the unit, measured in square meters
# - Flat Model - Classification of units by generation of which the flat was made, ranging from New Generation, DBSS, Improved, Apartment
# - Lease Commence Date - Starting point of a lease agreement, marking the beginning of the lease term during which the tenant has the right to use and occupy the leased property
# - Resale Price - Cost of the flat sold

# %%
from src.config import RAW_DATA_DIR, EXTERNAL_DATA_DIR
# Out:
# 2025-07-14 14:38:30.013 | INFO     | src.config:<module>:11 - PROJ_ROOT path is: /Users/Edward/Documents/GitHub/sg-flat-resale

# %%
import numpy as np
import pandas as pd

# %%
raw_data_files = ['ResaleFlatPricesBasedonApprovalDate19901999.csv',
                  'ResaleFlatPricesBasedonApprovalDate2000Feb2012.csv',
                  'ResaleFlatPricesBasedonRegistrationDateFromMar2012toDec2014.csv',
                  'ResaleFlatPricesBasedonRegistrationDateFromJan2015toDec2016.csv',
                  'ResaleflatpricesbasedonregistrationdatefromJan2017onwards.csv']

dfs = [pd.read_csv(RAW_DATA_DIR / file) for file in raw_data_files]
df = pd.concat(dfs, ignore_index=True)
df
# Out:
#           month        town  flat_type block       street_name storey_range  \
# 0       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4       1990-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...         ...         ...        ...   ...               ...          ...
# 941100  2024-11      YISHUN     5 ROOM  511B      YISHUN ST 51     10 TO 12
# 941101  2024-11      YISHUN     5 ROOM   850      YISHUN ST 81     01 TO 03
# 941102  2024-11      YISHUN  EXECUTIVE   405      YISHUN AVE 6     04 TO 06
# 941103  2024-11      YISHUN  EXECUTIVE   356    YISHUN RING RD     01 TO 03
# 941104  2024-11      YISHUN  EXECUTIVE   877      YISHUN ST 81     01 TO 03
#
#         floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0                 31.0        IMPROVED                 1977        9000.0
# 1                 31.0        IMPROVED                 1977        6000.0
# 2                 31.0        IMPROVED                 1977        8000.0
# 3                 31.0        IMPROVED                 1977        6000.0
# 4                 73.0  NEW GENERATION                 1976       47200.0
# ...                ...             ...                  ...           ...
# 941100           113.0        Improved                 2017      720000.0
# 941101           122.0        Improved                 1988      670000.0
# 941102           148.0      Maisonette                 1988      855500.0
# 941103           146.0      Maisonette                 1988      930000.0
# 941104           142.0       Apartment                 1987      865000.0
#
#            remaining_lease
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 941100  91 years 10 months
# 941101  62 years 09 months
# 941102  62 years 10 months
# 941103  62 years 10 months
# 941104  62 years 03 months
#
# [941105 rows x 11 columns]

# %%
# Combine "MULTI-GENERATION" and "MULTI GENERATION" flat types
df['flat_type'] = df['flat_type'].replace({'MULTI GENERATION' : 'MULTI-GENERATION'})

# Create date column by setting the day from each month to 01 since the original time format provided is has no day provided
df['date'] = pd.to_datetime(df['month'], format='%Y-%m')

# Create year column
df['year'] = df['date'].dt.strftime('%Y').astype('int64')

# Rename lease_commence_date and add year_leased column
df = df.rename({'lease_commence_date':'lease_year'}, axis=1)
df['years_leased'] = df['year'] - df['lease_year']

# Changing column entries to proper case
df['town'] = df['town'].apply(lambda x: x.title())
df['street_name'] = df['street_name'].apply(lambda x: x.title())
df['flat_model'] = df['flat_model'].apply(lambda x: x.title())
df['flat_type'] = df['flat_type'].apply(lambda x: x.title())

# Split storey_range into 2 columns and calculate number of storeys
df[['start_floor', 'end']] = df['storey_range'].str.extract(r'(\d+)\s+TO\s+(\d+)').astype(int)
df['storey_count'] = df['end'] - df['start_floor']

# Rearrange columns
df = df.loc[:, ['date', 'year', 'town', 'street_name', 'block', 'flat_type', 'flat_model', 'storey_count', 
                'start_floor', 'floor_area_sqm', 'lease_year', 'years_leased', 'resale_price']]

# %%
df.head()
# Out:
#         date  year        town       street_name block flat_type  \
# 0 1990-01-01  1990  Ang Mo Kio  Ang Mo Kio Ave 1   309    1 Room
# 1 1990-01-01  1990  Ang Mo Kio  Ang Mo Kio Ave 1   309    1 Room
# 2 1990-01-01  1990  Ang Mo Kio  Ang Mo Kio Ave 1   309    1 Room
# 3 1990-01-01  1990  Ang Mo Kio  Ang Mo Kio Ave 1   309    1 Room
# 4 1990-01-01  1990  Ang Mo Kio  Ang Mo Kio Ave 1   216    3 Room
#
#        flat_model  storey_count  start_floor  floor_area_sqm  lease_year  \
# 0        Improved             2           10            31.0        1977
# 1        Improved             2            4            31.0        1977
# 2        Improved             2           10            31.0        1977
# 3        Improved             2            7            31.0        1977
# 4  New Generation             2            4            73.0        1976
#
#    years_leased  resale_price
# 0            13        9000.0
# 1            13        6000.0
# 2            13        8000.0
# 3            13        6000.0
# 4            14       47200.0

# %% [markdown]
# The data source does not indicate whether the resale prices are adjusted for inflation. It may be necessary to adjust the prices for inflation.

# %%
infl = pd.read_csv(EXTERNAL_DATA_DIR / 'API_FP.CPI.TOTL.ZG_DS2_en_csv_v2_37769.csv')
infl
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 infl = pd.read_csv(EXTERNAL_DATA_DIR / 'API_FP.CPI.TOTL.ZG_DS2_en_csv_v2_37769.csv')
#       2 infl
#
# File /opt/anaconda3/envs/vanilla/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/envs/vanilla/lib/python3.12/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File /opt/anaconda3/envs/vanilla/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File /opt/anaconda3/envs/vanilla/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 3 fields in line 5, saw 70

# %%
# Create dataframe for percent inflation figures in Singapore
infl = pd.read_csv(EXTERNAL_DATA_DIR / 'API_FP.CPI.TOTL.ZG_DS2_en_csv_v2_37769.csv')
infl = infl.loc[infl['Country Name'] == 'Singapore', '1990':]
infl = infl.rename({208:'infl'})

# Transpose inflation dataframe
infl = infl.T
infl
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Create dataframe for percent inflation figures in Singapore
# ----> 2 infl = pd.read_csv(EXTERNAL_DATA_DIR / 'API_FP.CPI.TOTL.ZG_DS2_en_csv_v2_37769.csv')
#       3 infl = infl.loc[infl['Country Name'] == 'Singapore', '1990':]
#       4 infl = infl.rename({208:'infl'})
#
# File /opt/anaconda3/envs/vanilla/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/envs/vanilla/lib/python3.12/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File /opt/anaconda3/envs/vanilla/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File /opt/anaconda3/envs/vanilla/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 3 fields in line 5, saw 70

# %%
# Create dataframe for percent inflation figures in Singapore
infl = pd.read_csv(EXTERNAL_DATA_DIR / 'API_FP.CPI.TOTL.ZG_DS2_en_csv_v2_77.csv')
infl = infl.loc[infl['Country Name'] == 'Singapore', '1990':]
infl = infl.rename({208:'infl'})

# Add 2024 inflation as 0
infl['2024'] = 0

# Transpose inflation dataframe
infl = infl.T

# Calculate cumulative inflation figures (2024)
infl['cum_infl'] = infl.iloc[::-1,:].cumsum()

# Reset index, rename index column to 'year', set the dtype to int64
infl = infl.reset_index()
infl = infl.rename({'index':'year'}, axis=1)
infl['year'] = infl['year'].astype('int64')

# %%
# Merge original dataframe with the inflation dataframe on year
df = pd.merge(df, infl[['year', 'cum_infl']], on='year', how='left')

# Add column for resale price adjusted by inflation
df['infl_adj_price'] = df['resale_price'] + df['resale_price']*df['cum_infl']/100
df['infl_adj_price'] = df['infl_adj_price'].round(1)
df = df.drop('cum_infl', axis=1)
df.head()
# Out:
#         date  year        town       street_name block flat_type  \
# 0 1990-01-01  1990  Ang Mo Kio  Ang Mo Kio Ave 1   309    1 Room
# 1 1990-01-01  1990  Ang Mo Kio  Ang Mo Kio Ave 1   309    1 Room
# 2 1990-01-01  1990  Ang Mo Kio  Ang Mo Kio Ave 1   309    1 Room
# 3 1990-01-01  1990  Ang Mo Kio  Ang Mo Kio Ave 1   309    1 Room
# 4 1990-01-01  1990  Ang Mo Kio  Ang Mo Kio Ave 1   216    3 Room
#
#        flat_model  storey_count  start_floor  floor_area_sqm  lease_year  \
# 0        Improved             2           10            31.0        1977
# 1        Improved             2            4            31.0        1977
# 2        Improved             2           10            31.0        1977
# 3        Improved             2            7            31.0        1977
# 4  New Generation             2            4            73.0        1976
#
#    years_leased  resale_price  infl_adj_price
# 0            13        9000.0         14748.5
# 1            13        6000.0          9832.3
# 2            13        8000.0         13109.8
# 3            13        6000.0          9832.3
# 4            14       47200.0         77347.7

# %% [markdown]
# There is now a column for the resale price of each unit adjusted for inflation (2024)
# Source of inflation figures: World Bank (https://data.worldbank.org/indicator/FP.CPI.TOTL.ZG?contextual=default&end=2023&locations=SG&start=1961&view=chart)

# %%
df.describe()
# Out:
#                                 date           year   storey_count  \
# count                         941105  941105.000000  941105.000000
# mean   2006-11-23 23:34:11.583617024    2006.432752       2.014532
# min              1990-01-01 00:00:00    1990.000000       2.000000
# 25%              1999-02-01 00:00:00    1999.000000       2.000000
# 50%              2005-07-01 00:00:00    2005.000000       2.000000
# 75%              2014-10-01 00:00:00    2014.000000       2.000000
# max              2024-11-01 00:00:00    2024.000000       4.000000
# std                              NaN       9.498936       0.169860
#
#          start_floor  floor_area_sqm     lease_year   years_leased  \
# count  941105.000000   941105.000000  941105.000000  941105.000000
# mean        6.697608       95.686705    1988.422273      18.010479
# min         1.000000       28.000000    1966.000000      -2.000000
# 25%         4.000000       73.000000    1981.000000       9.000000
# 50%         7.000000       93.000000    1986.000000      16.000000
# 75%        10.000000      113.000000    1996.000000      25.000000
# max        49.000000      366.700000    2021.000000      58.000000
# std         4.841988       25.801141      10.809251      10.836415
#
#        resale_price  infl_adj_price
# count  9.411050e+05    9.411050e+05
# mean   3.252519e+05    4.151768e+05
# min    5.000000e+03    8.193600e+03
# 25%    1.950000e+05    2.773563e+05
# 50%    3.000000e+05    3.950378e+05
# 75%    4.220000e+05    5.276744e+05
# max    1.588000e+06    1.588000e+06
# std    1.746709e+05    1.908177e+05

# %%
df[df['years_leased']<0]
# Out:
#              date  year             town          street_name block  \
# 23271  1991-11-01  1991           Bishan         Bishan St 23   227
# 34246  1992-08-01  1992         Tampines       Tampines St 44   476
# 46535  1993-06-01  1993        Woodlands      Woodlands St 32   321
# 69033  1994-05-01  1994    Choa Chu Kang  Choa Chu Kang St 51   528
# 69609  1994-05-01  1994        Pasir Ris       Pasir Ris Dr 3   631
# 69977  1994-05-01  1994         Tampines       Tampines St 32   332
# 71709  1994-06-01  1994        Pasir Ris      Pasir Ris St 11   143
# 76424  1994-08-01  1994        Woodlands         Marsiling Rd   136
# 77301  1994-09-01  1994    Choa Chu Kang  Choa Chu Kang St 51   503
# 77902  1994-09-01  1994       Queenstown          Mei Ling St   150
# 78074  1994-09-01  1994         Tampines       Tampines St 33   322
# 78152  1994-09-01  1994         Tampines       Tampines St 82  842D
# 78275  1994-09-01  1994        Woodlands      Woodlands St 82   847
# 79664  1994-10-01  1994        Pasir Ris      Pasir Ris St 13   158
# 80079  1994-10-01  1994        Woodlands      Woodlands St 32   326
# 81480  1994-11-01  1994        Pasir Ris             Elias Rd   601
# 83393  1994-12-01  1994      Jurong West    Jurong West St 73   732
# 83394  1994-12-01  1994      Jurong West          Boon Lay Dr   261
# 83494  1994-12-01  1994  Kallang/Whampoa           Whampoa Rd   114
# 83566  1994-12-01  1994        Pasir Ris             Elias Rd   611
# 83969  1994-12-01  1994         Tampines       Tampines St 32   335
# 87450  1995-02-01  1995        Pasir Ris      Pasir Ris St 71   759
# 90798  1995-04-01  1995        Pasir Ris      Pasir Ris St 72   715
# 91217  1995-04-01  1995        Woodlands      Woodlands St 82   822
# 94414  1995-06-01  1995       Queenstown        Clarence Lane   132
# 100727 1995-09-01  1995    Choa Chu Kang  Choa Chu Kang Nth 6   556
# 101456 1995-09-01  1995        Pasir Ris      Pasir Ris St 71   775
# 104251 1995-10-01  1995        Pasir Ris      Pasir Ris St 71   753
# 108148 1995-11-01  1995        Woodlands      Woodlands St 82   874
# 108752 1995-12-01  1995       Ang Mo Kio     Ang Mo Kio St 21   253
# 110539 1995-12-01  1995        Pasir Ris      Pasir Ris Dr 10   738
# 110559 1995-12-01  1995        Pasir Ris      Pasir Ris St 72   724
# 111072 1995-12-01  1995         Tampines       Tampines St 33   357
# 121058 1996-04-01  1996    Bukit Panjang             Fajar Rd   453
# 126051 1996-06-01  1996            Bedok           Jln Tenaga   660
# 127931 1996-06-01  1996         Tampines       Tampines St 72   737
# 445042 2004-09-01  2004      Bukit Merah             Depot Rd  112A
# 449822 2004-11-01  2004      Bukit Merah             Depot Rd  109B
# 454942 2005-01-01  2005      Bukit Merah             Depot Rd  111A
# 454943 2005-01-01  2005      Bukit Merah             Depot Rd  112B
# 460048 2005-03-01  2005      Bukit Merah             Depot Rd  109A
# 462934 2005-04-01  2005      Bukit Merah             Depot Rd  111B
# 465387 2005-05-01  2005      Bukit Merah             Depot Rd  111B
# 467337 2005-06-01  2005       Ang Mo Kio     Ang Mo Kio St 31  316A
# 469831 2005-07-01  2005       Ang Mo Kio     Ang Mo Kio St 31  315A
# 469832 2005-07-01  2005       Ang Mo Kio     Ang Mo Kio St 31  316A
# 472225 2005-08-01  2005       Ang Mo Kio     Ang Mo Kio St 31  315A
# 472696 2005-08-01  2005      Bukit Merah             Depot Rd  111A
# 474757 2005-09-01  2005       Ang Mo Kio     Ang Mo Kio St 31  309A
# 475191 2005-09-01  2005      Bukit Merah             Depot Rd  111B
# 634577 2011-02-01  2011       Queenstown           Dover Cres   28B
#
#         flat_type  flat_model  storey_count  start_floor  floor_area_sqm  \
# 23271      4 Room     Model A             2            4           103.0
# 34246      5 Room     Model A             2            4           132.0
# 46535      5 Room    Improved             2            1           127.0
# 69033   Executive   Apartment             2            7           153.0
# 69609      4 Room     Model A             2           10           104.0
# 69977   Executive   Apartment             2            4           147.0
# 71709      4 Room     Model A             2            4           105.0
# 76424   Executive   Apartment             2            1           173.0
# 77301      5 Room    Improved             2           13           127.0
# 77902   Executive   Apartment             2           10           142.0
# 78074      4 Room     Model A             2            4           112.0
# 78152      5 Room     Model A             2            4           137.0
# 78275   Executive   Apartment             2            4           177.0
# 79664   Executive   Apartment             2            1           149.0
# 80079   Executive   Apartment             2           10           164.0
# 81480   Executive   Apartment             2            7           154.0
# 83393      5 Room    Improved             2            1           123.0
# 83394      5 Room    Improved             2            4           126.0
# 83494      5 Room    Improved             2            7           127.0
# 83566      5 Room    Improved             2           10           128.0
# 83969   Executive  Maisonette             2            4           146.0
# 87450      5 Room    Improved             2           10           128.0
# 90798   Executive   Apartment             2            7           143.0
# 91217      5 Room    Improved             2            1           129.0
# 94414      5 Room    Improved             2            7           121.0
# 100727  Executive   Apartment             2            1           149.0
# 101456     5 Room    Improved             2            4           125.0
# 104251     5 Room    Improved             2           10           128.0
# 108148     4 Room     Model A             2            4           111.0
# 108752     5 Room     Model A             2            1           138.0
# 110539     4 Room     Model A             2            7           104.0
# 110559     5 Room    Improved             2            7           124.0
# 111072     5 Room     Model A             2            4           132.0
# 121058  Executive   Apartment             2            7           142.0
# 126051     5 Room     Model A             2            1           138.0
# 127931  Executive   Apartment             2           10           140.0
# 445042     4 Room     Model A             2           22           100.0
# 449822     4 Room     Model A             2           25           100.0
# 454942     5 Room    Improved             2           22           115.0
# 454943     5 Room    Improved             2           22           116.0
# 460048     5 Room    Improved             2            7           116.0
# 462934     5 Room    Improved             2           22           116.0
# 465387     5 Room    Improved             2           22           116.0
# 467337     5 Room    Improved             2           28           110.0
# 469831     4 Room     Model A             2           13            95.0
# 469832     4 Room     Model A             2           25            95.0
# 472225     4 Room     Model A             2            1            95.0
# 472696     5 Room    Improved             2           22           115.0
# 474757     4 Room     Model A             2           16            95.0
# 475191     4 Room     Model A             2           10           100.0
# 634577     4 Room     Model A             2            7            95.0
#
#         lease_year  years_leased  resale_price  infl_adj_price
# 23271         1992            -1      135000.0        216555.4
# 34246         1993            -1      200000.0        313971.4
# 46535         1994            -1      145000.0        224347.8
# 69033         1995            -1      350000.0        533516.7
# 69609         1995            -1      160000.0        243893.3
# 69977         1996            -2      356000.0        542662.7
# 71709         1995            -1      180000.0        274380.0
# 76424         1995            -1      330000.0        503030.0
# 77301         1995            -1      235000.0        358218.4
# 77902         1995            -1      532000.0        810945.4
# 78074         1995            -1      218000.0        332304.7
# 78152         1995            -1      325000.0        495408.4
# 78275         1995            -1      405000.0        617355.0
# 79664         1995            -1      415000.0        632598.4
# 80079         1995            -1      380000.0        579246.7
# 81480         1995            -1      345000.0        525895.0
# 83393         1995            -1      260000.0        396326.7
# 83394         1995            -1      280000.0        426813.4
# 83494         1995            -1      395000.0        602111.7
# 83566         1995            -1      385000.0        586868.4
# 83969         1996            -2      409000.0        623452.4
# 87450         1996            -1      325000.0        485332.9
# 90798         1996            -1      450000.0        671999.4
# 91217         1996            -1      285000.0        425599.6
# 94414         1996            -1      393000.0        586879.5
# 100727        1996            -1      480000.0        716799.4
# 101456        1996            -1      340000.0        507732.9
# 104251        1996            -1      340000.0        507732.9
# 108148        1996            -1      222000.0        331519.7
# 108752        1996            -1      510000.0        761599.4
# 110539        1996            -1      235000.0        350933.0
# 110559        1996            -1      430000.0        642132.8
# 111072        1996            -1      408000.0        609279.5
# 121058        1997            -1      530000.0        782347.2
# 126051        1997            -1      575000.0        848772.9
# 127931        1997            -1      660000.0        974243.7
# 445042        2006            -2      348000.0        494165.7
# 449822        2006            -2      358000.0        508365.9
# 454942        2006            -1      388000.0        544515.0
# 454943        2006            -1      378000.0        530481.1
# 460048        2006            -1      416300.0        584230.9
# 462934        2006            -1      401999.0        564161.1
# 465387        2006            -1      383999.0        538900.1
# 467337        2006            -1      447500.0        628016.7
# 469831        2006            -1      310000.0        435050.7
# 469832        2006            -1      325000.0        456101.5
# 472225        2006            -1      295000.0        413999.8
# 472696        2006            -1      380000.0        533287.9
# 474757        2006            -1      323000.0        453294.7
# 475191        2006            -1      315000.0        442067.6
# 634577        2012            -1      616000.0        781074.9
